# %%
price=1000
discount=0.2
final_price=price-(price*discount)
print("Final Price after discount:",final_price)
# Out:
# Final Price after discount: 800.0

# %%
price=800
tax_rate=0.18
tax=price*tax_rate
total_price=price+tax
print("total price:",total_price)
# Out:
# total price: 944.0

# %%
price=800
tax_rate=0.12
tax=price*tax_rate
total_price=price+tax
print("total price:",total_price)
# Out:
# total price: 896.0

# %%
customer_name="Rahul_25"
age=25
salary=55000.75
is_fraud=False
print(type(customer_name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#customer details
age=30
salary=55000.0
loan_amount=200000
existing_loans=2

credit_score=720
is_citizen=True
#--Arithmetic Operators-->
emi=loan_amount/24
total_income_yearly=salary* 12
remaining_salary=total_income_yearly-(emi*12)
print("Monthly EMI:",emi)
print("Yearly  Income:",total_income_yearly)
print("Remaining salary after EMI:",remaining_salary)
# Out:
# Monthly EMI: 8333.333333333334
# Yearly  Income: 660000.0
# Remaining salary after EMI: 560000.0

# %%
#--comparissionOperators-->
print("Is credit score good?",credit_score>=700)
print("Is EMI less than 50% of salary?",emi<(salary+0.5))
print("Is age less than 60?",age<60)
# Out:
# Is credit score good? True
# Is EMI less than 50% of salary? True
# Is age less than 60? True

# %%
#--logical Operators-->
eligible=(credit_score>=700)and (emi<(salary*0.5)) and (age<60)and is_citizen
print("Loan Eligibility:",eligible)
# Out:
# Loan Eligibility: True

# %%
item1=1200
item2=800
item3=600
discount=0.1
total=item1+item2+item3
final_bill=total-(total*discount)
print("Total Bill:",total)
print("Final Bill after discount:", final_bill)
# Out:
# Total Bill: 2600
# Final Bill after discount: 2340.0

# %%
item1=1200
item2=800
item3=600
discount=0.1
total=item1+item2+item3
final_bill=total-(total*discount)
tax=final_bill+(final_bill)*0.18
print("Total Bill:",total)
print("Final Bill after discount:", final_bill)
print(tax)
# Out:
# Total Bill: 2600
# Final Bill after discount: 2340.0
# 2761.2

# %%
marks=int(input("Enter your score:"))
if marks>=95:
    print("Grade:A+(outstanding)")
elif marks>=90:
    print("Grade:A(Excellent)")
elif marks >=75:
    print("Grade B(Good)")
elif marks >=60:
    print ("Grade C(Needs Improvement)")
else:
    print("Grade:D( Fail)")
# Out:
# Enter your score:87
# Grade B(Good)

# %%
customers = ["Rahul","Priya","Amit","sneha","vikram"]
for name in customers:
  print("sending email to:",name)
# Out:
# sending email to: Rahul
# sending email to: Priya
# sending email to: Amit
# sending email to: sneha
# sending email to: vikram

# %%
for i in range(1,6):
  print("Reminder email number:",i)
# Out:
# Reminder email number: 1
# Reminder email number: 2
# Reminder email number: 3
# Reminder email number: 4
# Reminder email number: 5

# %%
customers = ["Rahul","Priya","Amit","sneha","vikram",25]
for name in customers:
  print("sending email to:",name)
# Out:
# sending email to: Rahul
# sending email to: Priya
# sending email to: Amit
# sending email to: sneha
# sending email to: vikram
# sending email to: 25

# %%
customers = ["lux",75,89,85,76,25]
for name in customers:
  print("sending email to:",name)
# Out:
# sending email to: lux
# sending email to: 75
# sending email to: 89
# sending email to: 85
# sending email to: 76
# sending email to: 25

# %%
students={"Rahul":85,"priya":92,"Amit":74}
for name, marks in students.items():
  if marks>=90:
    grade="A"
  elif marks>=75:
      grade="B"
  else:
        grade="C"
  print(f"student:{name},Marks:{marks},Grade:{grade}")
# Out:
# student:Rahul,Marks:85,Grade:B
# student:priya,Marks:92,Grade:A
# student:Amit,Marks:74,Grade:C

# %%
def greet(name) :
  print("Hello", name, "welcome to the bootcamp!")
greet("Rahul")
greet("Priya")
# Out:
# Hello Rahul welcome to the bootcamp!
# Hello Priya welcome to the bootcamp!

# %%
def Money(x,y):
  total=x+y
  return total
Money(1000,2000)
# Out:
# 3000

# %%
def Money(x,y):
  total=x+y
  return total
Money(1000,2000)
Money("abc","xyz")
# Out:
# 'abcxyz'

# %%
def Money(x,y):
  total=x+y
  return total
Money(1000,2000)
Money(1000.02,2000.05)
# Out:
# 3000.0699999999997

# %%
#eligible for voting or not
def eligibility(age):
  print(age)
  if age>=18:
    print("Person is eligible to vote")
  else:
    print("Person is not eligible")
eligibility(19)
eligibility(17)
# Out:
# 19
# Person is eligible to vote
# 17
# Person is not eligible

# %%
def calculate_discount(price, discount_percent):

    return price-(price* discount_percent / 100)

def apply_tax(price, tax_percent):

    return price+(price* tax_percent / 100)

price = 1000

discounted_price = calculate_discount(price, 10)

final_price = apply_tax(discounted_price, 18)

print("Final Price after discount and tax:", final_price)
# Out:
# Final Price after discount and tax: 1062.0

# %%
import math
print("square root of 25:",math.sqrt(25))
print("value of pi:",math.pi)
# Out:
# square root of 25: 5.0
# value of pi: 3.141592653589793

# %%
#Function to issue books

def issue_books (student_name, books):

    print(f"\n {student_name} borrowed:")

    for book in books:

        print("-", book)

# Function to calculate fine

def calculate_fine(days_late):

    fine_per_day = 5

    return days_late * fine_per_day

# Function to generate report

def student_report(student_name, books, days_late):

    issue_books(student_name, books)

    fine =calculate_fine(days_late)

    print(f"Fine to be paid: {fine}\n")

# Example usage

student_report("Rahul", ["Python Basics", "Data Science 101"], 3)

student_report("Priya", ["Machine Learning"], 0)
# Out:
#  Rahul borrowed:
# - Python Basics
# - Data Science 101
# Fine to be paid: 15
#
#
#  Priya borrowed:
# - Machine Learning
# Fine to be paid: 0

# %% [markdown]
# Add a limit max 3 books per student
#
# 2 Allow students to return books early 4 no fine
#
# 3 Add membership type (Normal/Premium) Prenium users pay less fine.
#
# 4 Track how many total books are borrowed.
